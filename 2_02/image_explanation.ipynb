# %%
import sys
import os
# 현재 디렉토리의 상위 디렉토리를 추가
sys.path.append(os.path.join(os.getcwd(), '..'))
from openai import OpenAI
from config.const import OPENAI_API_KEY

# %%
client = OpenAI(api_key= OPENAI_API_KEY)

# %%
messages = [
    {
        "role" : "user",
        "content" : [
            {
                "type" : "text",
                "text" : "이 이미지에 대해 설명해 주세요. 그리고 주요 키워드를 분석해서 5가지를 나열해주세요. "
            },
            {
                "type" : "image_url",
                "image_url" : {
                    "url" : "https://images.unsplash.com/photo-1758240689297-d8613ca753f3?q=80&w=1740&auto=format&fit=crop&ixlib=rb-4.1.0&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D",
                },
            },
        ],
    }
]

# %%
response = client.chat.completions.create(
    model="gpt-4o",
    messages=messages
)

# %%
response
# Out:
# ChatCompletion(id='chatcmpl-CI7xJ5tDpCazSQ0D42ia3tKmFjev1', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='이미지는 현대적이고 깔끔한 주방을 보여줍니다. 이 주방은 밝고 환하게 조명이 배치되어 있으며, 중앙에는 넓은 아일랜드 식탁이 있습니다. 식탁 위에는 과일과 음료가 놓여 있습니다. 주방은 전체적으로 화이트와 그레이 톤으로 꾸며져 있고, 벽에는 대리석 타일이 사용되었습니다. 창문을 통해 자연광이 들어오며, 입구로 보이는 유리문이 공간을 더욱 넓어 보이게 합니다. 여러 개의 펜던트 조명이 천장에서 내려오고, 곳곳에 실용적인 주방 도구들이 배치되어 있습니다.\n\n주요 키워드:\n1. 현대적 디자인\n2. 밝은 조명\n3. 대리석 타일\n4. 아일랜드 식탁\n5. 자연광', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None, annotations=[]))], created=1758436521, model='gpt-4o-2024-08-06', object='chat.completion', service_tier='default', system_fingerprint='fp_cbf1785567', usage=CompletionUsage(completion_tokens=190, prompt_tokens=1136, total_tokens=1326, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_toke
# ...

# %%
import base64

def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')
    
image_path = "./image.png"

# %%
print(encode_image(image_path))
# Out:
# ...

# %%
messages = [
    {
        "role" : "user",
        "content" : [
            {
                "type" : "text",
                "text" : "이 이미지에 대해 설명해 주세요. 그리고 주요 키워드를 분석해서 5가지를 나열해주세요. "
            },
            {
                "type" : "image_url",
                "image_url" : {
                    "url" : f"data:image/png;base64,{encode_image(image_path)}",
                },
            },
        ],
    }
]

# %%
response = client.chat.completions.create(
    model="gpt-4o",
    messages = messages
)

response.choices[0].message.content
# Out:
# '이 이미지는 귀여운 고양이가 작은 왕관을 쓰고 있는 모습입니다. 고양이는 파란 눈을 가지고 있으며, 배경은 밝고 부드러운 색상으로 이루어져 있습니다.\n\n주요 키워드:\n1. 고양이\n2. 왕관\n3. 파란 눈\n4. 귀여움\n5. 애니메이션 스타일'
